# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

path = '/home/noemi/Documents/LBM_Runs/DiskInGravity/data/input.param'
f = open(path, 'r')
data = f.readlines()
for line in data:
    words=line.split()
Nxs=words[0]
Nx=int(Nxs)
Nys=words[1]
Ny=int(Nys)
Lxs=words[2]
Lx=float(Lxs)
Lys=words[3]
Ly=float(Lys)

#print(Lx)
ux=np.zeros([Nx+2,Ny+2])
uy=np.zeros([Nx+2,Ny+2])
xx=np.linspace(0,Lx+1,Nx+2)
yy=np.linspace(0,Ly+1,Ny+2)
print(len(ux))
#print(xx)
uu=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/data/usnap')
uux=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocity_math_vx.dat')
uuy=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocity_math_vy.dat')
uux_p = (uux.reshape(Nx+2,Ny+2))
uuy_p = (uuy.reshape(Nx+2,Ny+2))
#plt.plot(uux_p[0,:])
np.set_printoptions(threshold=np.nan)

#print(uux_p)


surface=np.zeros([Nx,Ny])
surface_x = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/surface_pointx.dat')
#print(surface_x)
surface_y = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/surface_pointy.dat')
#print(surface_y)


drag = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/drag.dat')
lift = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/lift.dat')

sigma_xx = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/sigma_xx.dat')
sigma_xy = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/sigma_xy.dat')
sigma_yx = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/sigma_yx.dat')
sigma_yy = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/sigma_yy.dat')

stream_theo = np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/stream_theo.dat')
stream_theo_p = stream_theo.reshape(Nx,Ny)
#print(stream_theo_p)

drag_p = drag.reshape(Nx,Ny)
lift_p = lift.reshape(Nx,Ny)

sigma_xx_p=sigma_xx.reshape(Nx,Ny)
sigma_xy_p=sigma_xy.reshape(Nx,Ny)
sigma_yx_p=sigma_yx.reshape(Nx,Ny)
sigma_yy_p=sigma_yy.reshape(Nx,Ny)

plt.xlim(0, Nx+1)
plt.ylim(0, Ny+1)
plt.contour(stream_theo_p.T,50)
plt.colorbar()
plt.axis('equal')
plt.show()


#plt.streamplot(xx,yy,uux_p.T,uuy_p.T,density=[1,1], color='purple')
#plt.plot(surface_x,surface_y,'r.')
plt.axis('equal')
plt.imshow(drag_p.T)
#plt.plot([68],[83],'r.',color='blue')
plt.title('Drag')
plt.colorbar()
plt.gca().invert_yaxis()
plt.show()
plt.axis('equal')
plt.imshow(lift_p.T)
plt.title('Lift')
plt.colorbar()
plt.show()
plt.imshow(sigma_xx_p.T)
plt.title('Sigma_xx')
plt.colorbar()
plt.show()
plt.imshow(sigma_xy_p.T)
plt.title('Sigma_xy')
plt.colorbar()
plt.show()
plt.imshow(sigma_yx_p.T)
plt.title('Sigma_yx')

plt.colorbar()
plt.show()
plt.imshow(sigma_yy_p.T)
plt.title('Sigma_yy')

plt.colorbar()
plt.show()
# Out:
# 130

# %%
uuy=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocity_math_vy.dat')

# %%
uuy_p = (uuy.reshape(Nx+2,Ny+2))

# %%
plt.plot(uuy_p[0,:])

# %%
uux=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocity_math_vx.dat')
uux_theo=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/ux_theo.dat')

# %%
uux_p = (uux.reshape(Nx+2,Ny+2))
uux_theo_p = (uux_theo.reshape(Nx,Ny))

# %%
#plt.ylim(0, 0.02)
plt.plot(uux_p[100,:],'b.')
#print(uux_p[0,:])
plt.plot(uux_theo_p[100,:],'r.')

# %%
uuy=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocity_math_vy.dat')
uuy_theo=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/uy_theo.dat')

# %%
uuy_p = (uuy.reshape(Nx+2,Ny+2))
uuy_theo_p = (uuy_theo.reshape(Nx,Ny))

# %%
#plt.ylim(0, 2)
plt.plot(uuy_p[100,:],'b.')
#print(uux_p[0,:])
plt.plot(uuy_theo_p[100,:],'r.')

# %%
plt.contour(uux_p.T,cmap='jet')
plt.colorbar(cmap='jet')

# %%
from numpy import asarray
rho_a = []
for c in range(1,300,100):
    ux=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocitx_series%05i.dat' % c)
    uy=np.loadtxt('/home/noemi/Documents/LBM_Runs/DiskInGravity/velocity_series%05i.dat' % c)
    ux_p = (ux.reshape(Nx+2,Ny+2))
    uy_p = (uy.reshape(Nx+2,Ny+2))
    #print(rho_p.shape) 
    plt.imshow(ux_p.T, cmap='jet')
    #plt.imshow(uy_p.T, cmap='jet')
    plt.colorbar(cmap='jet')
    plt.plot(surface_x-1,surface_y-1,'r.')
    #plt.plot(rho_p[0,:])
    plt.show()
